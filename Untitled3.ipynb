# %%
#provided home phone and Internet services to 7043 customers in California in Q3.
import pandas as pd

# %%
df = pd.read_csv('WA_Fn-UseC_-Telco-Customer-Churn.csv')
print(df.tail(4))
# Gender
# Senior Citizen
# Partner 
# Dependents
# Tenure
# PhoneService
# MultipleLines
# InternetService
# OnlineSecurity
# DeviceProtection
# TechSupport
# StreamingTV
# StreamingMovies
# Cont
# PaperlessBilling
# PaymentMethod
# MonthlyCharges
# TotalCh
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 7039          Yes               Yes     Fiber optic             No  ...
# 7040           No  No phone service             DSL            Yes  ...
# 7041          Yes               Yes     Fiber optic             No  ...
# 7042          Yes                No     Fiber optic            Yes  ...
#
#      DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 7039              Yes          No         Yes             Yes        One year
# 7040               No          No          No              No  Month-to-month
# 7041               No          No          No              No  Month-to-month
# 7042              Yes         Yes         Yes             Yes        Two year
#
#      PaperlessBilling              PaymentMethod MonthlyCharges  TotalCharges  \
# 7039              Yes    Credit card (automatic)         103.20        7362.9
# 7040              Yes           Electronic check          29.60        346.45
# 7041              Yes               Mailed check          74.40         306.6
# 7042              Yes  Bank transfer (automatic)         105.65        6844.5
#
#      Churn
# 7039    No
# 7040    No
# 7041   Yes
# 7042    No
#
# [4 rows x 21 columns]

# %%
# It does not matter as it is still a binomial distribution
# Create the function
def transform_value(x):
    if x == 'Yes':
        result = 0
    else:
        result = 1
    return result
# Test the function
result1 = transform_value("Yes")
print(result1)
result2 = transform_value("No")
print(result2)

df['Churn'] = df['Churn'].apply(transform_value)

print(df['Churn'])
# Out:
# 0
# 1
# 0       1
# 1       1
# 2       0
# 3       1
# 4       0
#        ..
# 7038    1
# 7039    1
# 7040    1
# 7041    0
# 7042    1
# Name: Churn, Length: 7043, dtype: int64

# %%
correlation_matrix = df.corr()
print(correlation_matrix)
# Out:
#                SeniorCitizen    tenure     Churn
# SeniorCitizen       1.000000  0.016567 -0.150889
# tenure              0.016567  1.000000  0.352229
# Churn              -0.150889  0.352229  1.000000
# C:\Users\cecil\AppData\Local\Temp\ipykernel_13776\1752422992.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = df.corr()

# %%
# Build plots 
import matplotlib.pyplot as plt

# %%
# Analyze any trends to find the reasons behind customer churns
# Create a plot with Churn and the gender of the customer
cross_tab = pd.crosstab(df['gender'], df['InternetService'])
print(cross_tab)
cross_tab.plot(kind='bar', stacked=True, color=['red', 'green', 'pink'])
plt.show()
# More women remained in the company compared to men
# Out:
# InternetService   DSL  Fiber optic   No
# gender
# Female           1188         1553  747
# Male             1233         1543  779

# %%
# Create a plot for the senior citizen 
# 0 means someone is less than 65 years old
# 1 means someone is more than 65 years old
# 0 means they stayed with the same company/ 1 means they left
cross_tab2 = pd.crosstab(df['SeniorCitizen'], df['Churn'])
print(cross_tab2)
cross_tab2.plot(kind='bar', stacked=True, color=['blue', 'green'])
plt.show()
# Out:
# Churn             0     1
# SeniorCitizen
# 0              1393  4508
# 1               476   666

# %%
# Most their customers have less than 65 years old
# On average, ...% are likely to leave the company regardless of their age
ratio_cust_churn_less_65 = cross_tab2.iloc[0, 1]/cross_tab2.iloc[0, 0]
print(ratio_cust_churn_less_65)
ratio_cust_churn_abv_65 = cross_tab2.iloc[1, 1]/cross_tab2.iloc[1, 0]
print(ratio_cust_churn_abv_65)

# We can assume that customers who are less than 65 are more likely to leave the company
# Out:
# 3.236180904522613
# 1.3991596638655461

# %%
cross_tab3 = pd.crosstab(df['InternetService'], df['Churn'])
print(cross_tab3)
cross_tab3.plot(kind='bar', stacked=True, color=['blue', 'green'])
plt.show()
# It appears that people with Fiber Optic tends to stay in the company
# Out:
# Churn               0     1
# InternetService
# DSL               459  1962
# Fiber optic      1297  1799
# No                113  1413

# %%
# 0 means they stayed with the same company/ 1 means they left
ratio_cust_churn_DSL = cross_tab3.iloc[0, 1]/cross_tab3.iloc[0, 0]
print(ratio_cust_churn_DSL)
ratio_cust_churn_fib_opt = cross_tab3.iloc[1, 1]/cross_tab3.iloc[1, 0]
print(ratio_cust_churn_fib_opt)
ratio_cust_churn_no_int_serv = cross_tab3.iloc[2, 1]/cross_tab3.iloc[2, 0]
print(ratio_cust_churn_no_int_serv)
# Customers who do not use internet service are more likely to leave followed by the customers who are using fiber optics
# Out:
# 4.2745098039215685
# 1.387047031611411
# 12.504424778761061

# %%
# PaymentMethod
cross_tab4 = pd.crosstab(df['PaymentMethod'], df['Churn'])
print(cross_tab4)
cross_tab4.plot(kind='bar', stacked=True, color=['blue', 'green'])
plt.show()

# People with electronic check tends to stay the most
# Out:
# Churn                         0     1
# PaymentMethod
# Bank transfer (automatic)   258  1286
# Credit card (automatic)     232  1290
# Electronic check           1071  1294
# Mailed check                308  1304

# %%
ratio_cust_bank = cross_tab4.iloc[0, 1]/cross_tab4.iloc[0, 0]
print(ratio_cust_bank)
ratio_cust_churn_credit_card = cross_tab4.iloc[1, 1]/cross_tab4.iloc[1, 0]
print(ratio_cust_churn_credit_card )
ratio_cust_churn_elec_check = cross_tab4.iloc[2, 1]/cross_tab4.iloc[2, 0]
print(ratio_cust_churn_elec_check)
ratio_cust_churn_mail_check = cross_tab4.iloc[3, 1]/cross_tab4.iloc[3, 0]
print(ratio_cust_churn_mail_check)
# It appears that customers who utilizes electronic check are less likely to churn
# Out:
# 4.984496124031008
# 5.560344827586207
# 1.2082166199813258
# 4.233766233766234

# %%
# Partner
# Let's calculate the percentage
cross_tab5 = pd.crosstab(df['Partner'], df['Churn'])
print(cross_tab5) 

for components, row in cross_tab5():
    
    df[f'{component}_Percentage'] = df[component] / df[components].sum(axis=1) * 100

# Set the figure size
plt.figure(figsize=(8, 6))

# Create the stacked bar chart
bottom = 0
for component in components:
    plt.bar(df['Category'], df[component], label=component, bottom=bottom)
    bottom += df[component]

# Add data labels (percentages) on top of the bars
for category in df['Category']:
    for component in components:
        plt.text(category, df[df['Category'] == category][component].values[0] / 2, f'{df[df["Category"] == category][f"{component}_Percentage"].values[0]:.1f}%', ha='center', va='center')

# Add labels, legend, and title
plt.xlabel('Category')
plt.ylabel('Value')
plt.legend()
plt.title('Stacked Bar Chart with Percentages')

# Show the plot
plt.show()

cross_tab5.plot(kind='bar', stacked=True, color=['blue', 'green'])
plt.show()
# Out:
# Churn       0     1
# Partner
# No       1200  2441
# Yes       669  2733
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 6
#       3 cross_tab5 = pd.crosstab(df['Partner'], df['Churn'])
#       4 print(cross_tab5)
# ----> 6 for components, row in cross_tab5():
#       8     df[f'{component}_Percentage'] = df[component] / df[components].sum(axis=1) * 100
#      10 # Set the figure size
#
# TypeError: 'DataFrame' object is not callable

# %%
# Partner
cross_tab6 = pd.crosstab(df['Dependents'], df['Churn'])
print(cross_tab6)
cross_tab6.plot(kind='bar', stacked=True, color=['blue', 'green'])
plt.show()
# Out:
# Churn          0     1
# Dependents
# No          1543  3390
# Yes          326  1784

# %%
ratio_cust_no_partner = cross_tab6.iloc[0, 1]/cross_tab6.iloc[0, 0]
print(ratio_cust_no_partner)
ratio_cust_churn_yes_partner = cross_tab6.iloc[1, 1]/cross_tab6.iloc[1, 0]
print(ratio_cust_churn_yes_partner)
# It appears that customers who have no partner are less likely to churn
# Out:
# 2.1970187945560595
# 5.47239263803681

# %%
import numpy as np

# %%
# Tenure: Indicates the total amount of months that the customer has been with the company 
# by the end of the quarter specified above
# Cross tab can be only applied to two categorical variables
# It is crucial to build categories 

#The customer with more than 36 months are considered verylongtermcustomers
#The customer between 12 and 35 months are considered longtermcustomers
#The customer between 6 and 11 months are considered midtermcustomers
# The customer between 3 and 5 months are considered earlystagetermcustomers
# The customer with less than are considered newcustomers

# First filter the data frame to only include churn and tenure
# Then apply the conditional statements
filtered_df = df[['tenure','Churn']]

first_condition = filtered_df['tenure'] > 36
second_condition = (filtered_df['tenure'] >= 12) & (filtered_df['tenure'] <= 35)
third_condition = (filtered_df['tenure'] >= 6) & (filtered_df['tenure'] <= 11)
fourth_condition = (filtered_df['tenure'] >= 3) & (filtered_df['tenure'] <= 5)
fifth_condition = filtered_df['tenure'] < 3

filtered_df2 = df.copy()

conditions = [
    first_condition,
    second_condition,
    third_condition,
    fourth_condition,
    fifth_condition
]

values = [
    'verylongtermcustomers',
    'longtermcustomers',
    'midtermcustomers',
    'earlystagetermcustomers',
    'newcustomers'
]

# Create the 'CustomerType' column based on conditions and values
df['CustomerType'] = np.select(conditions, values, default='unknowncustomers')

# Display the DataFrame
print(df)
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# 1             Yes                No             DSL            Yes  ...
# 2             Yes                No             DSL            Yes  ...
# 3              No  No phone service             DSL            Yes  ...
# 4             Yes                No     Fiber optic             No  ...
# ...           ...               ...             ...            ...  ...
# 7038          Yes               Yes             DSL            Yes  ...
# 7039          Yes               Yes     Fiber optic             No  ...
# 7040           No  No phone service             DSL            Yes  ...
# 7041          Yes               Yes     Fiber optic             No  ...
# 7042          Yes                No     Fiber optic            Yes  ...
#
#      TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0             No          No              No  Month-to-month              Yes
# 1             No          No              No        One year               No
# 2             No          No              No  Month-to-month              Yes
# 3            Yes          No              No        One year               No
# 4             No          No              No  Month-to-month              Yes
# ...          ...         ...             ...             ...              ...
# 7038         Yes         Yes             Yes        One year              Yes
# 7039          No         Yes             Yes        One year              Yes
# 7040          No          No              No  Month-to-month              Yes
# 7041          No          No              No  Month-to-month              Yes
# 7042         Yes         Yes             Yes        Two year              Yes
#
#                   PaymentMethod MonthlyCharges TotalCharges  Churn  \
# 0              Electronic check          29.85        29.85      1
# 1                  Mailed check          56.95       1889.5      1
# 2                  Mailed check          53.85       108.15      0
# 3     Bank transfer (automatic)          42.30      1840.75      1
# 4              Electronic check          70.70       151.65      0
# ...                         ...            ...          ...    ...
# 7038               Mailed check          84.80       1990.5      1
# 7039    Credit card (automatic)         103.20       7362.9      1
# 7040           Electronic check          29.60       346.45      1
# 7041               Mailed check          74.40        306.6      0
# 7042  Bank transfer (automatic)         105.65       6844.5      1
#
#                  CustomerType
# 0                newcustomers
# 1           longtermcustomers
# 2                newcustomers
# 3       verylongtermcustomers
# 4                newcustomers
# ...                       ...
# 7038        longtermcustomers
# 7039    verylongtermcustomers
# 7040         midtermcustomers
# 7041  earlystagetermcustomers
# 7042    verylongtermcustomers
#
# [7043 rows x 22 columns]

# %%
# 0 means they stayed with the same company and 1 means they left
cross_tab7 = pd.crosstab(df['CustomerType'], df['Churn'])
print(cross_tab7)
cross_tab7.plot(kind='bar', stacked=True, color=['blue', 'green'])
plt.show()
# Out:
# Churn                      0     1
# CustomerType
# earlystagetermcustomers  241   268
# longtermcustomers        502  1421
# midtermcustomers         255   443
# newcustomers             503   359
# unknowncustomers          10    40
# verylongtermcustomers    358  2643

# %%
ratio_cust_earlystagecus = cross_tab7.iloc[0, 1]/cross_tab7.iloc[0, 0]
print(ratio_cust_earlystagecus)
ratio_cust_longtermcus = cross_tab7.iloc[1, 1]/cross_tab7.iloc[1, 0]
print(ratio_cust_longtermcus)
ratio_cust_midtermcus = cross_tab7.iloc[2, 1]/cross_tab7.iloc[2, 0]
print(ratio_cust_midtermcus)
ratio_cust_newcus = cross_tab7.iloc[3, 1]/cross_tab7.iloc[3, 0]
print(ratio_cust_newcus)
ratio_cust_verylongterm = cross_tab7.iloc[5, 1]/cross_tab7.iloc[5, 0]
print(ratio_cust_verylongterm)

# It appears that very long term constumers are 7 times more likely to leave. 
# Early stage customers are less likely to leave
# Out:
# 1.112033195020747
# 2.8306772908366535
# 1.7372549019607844
# 0.7137176938369781
# 7.38268156424581

# %%
cross_tab8 = pd.crosstab(df['PhoneService'], df['Churn'])
print(cross_tab8)
cross_tab8.plot(kind='bar', stacked=True, color=['blue', 'green'])
plt.show()
# Customers who have phone service are more likely to leave.
# Out:
# Churn            0     1
# PhoneService
# No             170   512
# Yes           1699  4662

# %%
# Indicates if the customer subscribes to multiple telephone lines with the company: Yes, No
cross_tab9= pd.crosstab(df['MultipleLines'], df['Churn'])
print(cross_tab9)
cross_tab9.plot(kind='bar', stacked=True, color=['blue', 'green'])
plt.show()
# Out:
# Churn               0     1
# MultipleLines
# No                849  2541
# No phone service  170   512
# Yes               850  2121

# %%
#  Indicates if the customer subscribes to an additional online security service provided by the company
cross_tab10 = pd.crosstab(df['OnlineSecurity'], df['Churn'])
print(cross_tab10)
cross_tab10.plot(kind='bar', stacked=True, color=['blue', 'green'])
plt.show()
# Out:
# Churn                   0     1
# OnlineSecurity
# No                   1461  2037
# No internet service   113  1413
# Yes                   295  1724

# %%
# Add the two columns and calculate the percentage then build a pie chart

#Since they see it as integers, don't add strings
cross_tab3['Total'] = cross_tab3[0] + cross_tab3[1]
cross_tab3['Perct_churn'] =  cross_tab3[0]/cross_tab3['Total']
print(cross_tab3)
# Out:
# Churn               0     1  Total  Perct_churn
# InternetService
# DSL               459  1962   2421     0.189591
# Fiber optic      1297  1799   3096     0.418928
# No                113  1413   1526     0.074050

# %%
# Indicates if the customer subscribes to an additional device protection plan for their Internet equipment provided by the company: Yes, No
cross_tab11 = pd.crosstab(df['DeviceProtection'], df['Churn'])
print(cross_tab11)
cross_tab11.plot(kind='bar', stacked=True, color=['blue', 'green'])
plt.show()
# Out:
# Churn                   0     1
# DeviceProtection
# No                   1211  1884
# No internet service   113  1413
# Yes                   545  1877

# %%
# Indicates if the customer subscribes to an additional technical support plan from the company with reduced wait times: Yes, No
cross_tab12 = pd.crosstab(df['TechSupport'], df['Churn'])
print(cross_tab12)
cross_tab12.plot(kind='bar', stacked=True, color=['blue', 'green'])
plt.show()
# Out:
# Churn                   0     1
# TechSupport
# No                   1446  2027
# No internet service   113  1413
# Yes                   310  1734

# %%
ratio_cust_no_tech = cross_tab12.iloc[0, 1]/cross_tab12.iloc[0, 0]
print(ratio_cust_no_tech)
ratio_cust_no_int = cross_tab12.iloc[1, 1]/cross_tab12.iloc[1, 0]
print(ratio_cust_no_int)
ratio_cust_yes_int = cross_tab12.iloc[2, 1]/cross_tab12.iloc[2, 0]
print(ratio_cust_yes_int)

# It appears that customers with no internet service are more likely to leave followed by customers who subscribes to additional tech support
# Out:
# 1.4017980636237897
# 12.504424778761061
# 5.593548387096774

# %%
# Indicates if the customer uses their Internet service to stream television programing from a third party provider: Yes, No. 
# The company does not charge an additional fee for this service.
cross_tab13 = pd.crosstab(df['StreamingTV'], df['Churn'])
print(cross_tab13)
cross_tab13.plot(kind='bar', stacked=True, color=['blue', 'green'])
plt.show()
# Out:
# Churn                  0     1
# StreamingTV
# No                   942  1868
# No internet service  113  1413
# Yes                  814  1893

# %%
ratio_cust_no_stream = cross_tab13.iloc[0, 1]/cross_tab13.iloc[0, 0]
print(ratio_cust_no_stream)
ratio_cust_no_int1 = cross_tab13.iloc[1, 1]/cross_tab13.iloc[1, 0]
print(ratio_cust_no_int1)
ratio_cust_yes_stream = cross_tab13.iloc[2, 1]/cross_tab13.iloc[2, 0]
print(ratio_cust_yes_stream)

# It appears that customers service without internet service are more likely to leave followed by those who are streaming TV
# Out:
# 1.9830148619957537
# 12.504424778761061
# 2.3255528255528257

# %%
# Indicates if the customer uses their Internet service to stream movies from a third party provider: Yes, No. 
# The company does not charge an additional fee for this service.
cross_tab14 = pd.crosstab(df['StreamingMovies'], df['Churn'])
print(cross_tab14)
cross_tab14.plot(kind='bar', stacked=True, color=['blue', 'green'])
plt.show()
# Out:
# Churn                  0     1
# StreamingMovies
# No                   938  1847
# No internet service  113  1413
# Yes                  818  1914

# %%
ratio_cust_no_streammov = cross_tab14.iloc[0, 1]/cross_tab14.iloc[0, 0]
print(ratio_cust_no_streammov)
ratio_cust_no_int2 = cross_tab14.iloc[1, 1]/cross_tab14.iloc[1, 0]
print(ratio_cust_no_int2)
ratio_cust_yes_streammov = cross_tab14.iloc[2, 1]/cross_tab14.iloc[2, 0]
print(ratio_cust_yes_streammov)

# It appears that customers service without internet service are more likely to leave followed by those who are streaming movies
# Out:
# 1.9690831556503199
# 12.504424778761061
# 2.3398533007334965

# %%
# Indicates the customer’s current contract type: Month-to-Month, One Year, Two Year.
cross_tab15 = pd.crosstab(df['Contract'], df['Churn'])
print(cross_tab15)
cross_tab15.plot(kind='bar', stacked=True, color=['blue', 'green'])
plt.show()
# Out:
# Churn              0     1
# Contract
# Month-to-month  1655  2220
# One year         166  1307
# Two year          48  1647

# %%
ratio_churn_m_t_m = cross_tab15.iloc[0, 1]/cross_tab15.iloc[0, 0]
print(ratio_churn_m_t_m)
ratio_churn_one_year = cross_tab15.iloc[1, 1]/cross_tab15.iloc[1, 0]
print(ratio_churn_one_year)
ratio_cust_two_year = cross_tab15.iloc[2, 1]/cross_tab15.iloc[2, 0]
print(ratio_cust_two_year)

# It appears that customers with two year contracts are more likely to leave as well as those with a one-year contract
# Out:
# 1.3413897280966767
# 7.873493975903615
# 34.3125

# %%
# Indicates if the customer has chosen paperless billing: Yes, No
cross_tab16 = pd.crosstab(df['PaperlessBilling'], df['Churn'])
print(cross_tab16)
cross_tab16.plot(kind='bar', stacked=True, color=['blue', 'green'])
plt.show()
# Out:
# Churn                0     1
# PaperlessBilling
# No                 469  2403
# Yes               1400  2771

# %%
ratio_churn_no_paper = cross_tab16.iloc[0, 1]/cross_tab16.iloc[0, 0]
print(ratio_churn_no_paper )
ratio_churn_yes_paper = cross_tab16.iloc[1, 1]/cross_tab16.iloc[1, 0]
print(ratio_churn_yes_paper )

# It appears than customers with no paperlessbilling are more likely to leave
# Out:
# 5.1236673773987205
# 1.9792857142857143

# %%
# Indicates the customer’s current total monthly charge for all their services from the company.
# Low below 50
# medium between 50 and 100
# high above 100

# %%
# First filter the data frame to only include churn and tenure
# Then apply the conditional statements

first_condition2 = df['MonthlyCharges'] > 100
second_condition2 = (df['MonthlyCharges'] >= 50) & (df['MonthlyCharges'] <= 100)
third_condition2 = df['MonthlyCharges'] < 50

filtered_df3 = df.copy()

conditions = [
    first_condition2,
    second_condition2,
    third_condition2
]

values = [
    'high',
    'medium',
    'low'
]

# Create the 'CustomerType' column based on conditions and values
df['MonthlyCharges'] = np.select(conditions, values)

# Display the DataFrame
print(df)
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# 1             Yes                No             DSL            Yes  ...
# 2             Yes                No             DSL            Yes  ...
# 3              No  No phone service             DSL            Yes  ...
# 4             Yes                No     Fiber optic             No  ...
# ...           ...               ...             ...            ...  ...
# 7038          Yes               Yes             DSL            Yes  ...
# 7039          Yes               Yes     Fiber optic             No  ...
# 7040           No  No phone service             DSL            Yes  ...
# 7041          Yes               Yes     Fiber optic             No  ...
# 7042          Yes                No     Fiber optic            Yes  ...
#
#      TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0             No          No              No  Month-to-month              Yes
# 1             No          No              No        One year               No
# 2             No          No              No  Month-to-month              Yes
# 3            Yes          No              No        One year               No
# 4             No          No              No  Month-to-month              Yes
# ...          ...         ...             ...             ...              ...
# 7038         Yes         Yes             Yes        One year              Yes
# 7039          No         Yes             Yes        One year              Yes
# 7040          No          No              No  Month-to-month              Yes
# 7041          No          No              No  Month-to-month              Yes
# 7042         Yes         Yes             Yes        Two year              Yes
#
#                   PaymentMethod MonthlyCharges TotalCharges Churn  \
# 0              Electronic check            low        29.85     1
# 1                  Mailed check         medium       1889.5     1
# 2                  Mailed check         medium       108.15     0
# 3     Bank transfer (automatic)            low      1840.75     1
# 4              Electronic check         medium       151.65     0
# ...                         ...            ...          ...   ...
# 7038               Mailed check         medium       1990.5     1
# 7039    Credit card (automatic)           high       7362.9     1
# 7040           Electronic check            low       346.45     1
# 7041               Mailed check         medium        306.6     0
# 7042  Bank transfer (automatic)           high       6844.5     1
#
#                  CustomerType
# 0                newcustomers
# 1           longtermcustomers
# 2                newcustomers
# 3       verylongtermcustomers
# 4                newcustomers
# ...                       ...
# 7038        longtermcustomers
# 7039    verylongtermcustomers
# 7040         midtermcustomers
# 7041  earlystagetermcustomers
# 7042    verylongtermcustomers
#
# [7043 rows x 22 columns]

# %%
cross_tab17 = pd.crosstab(df['MonthlyCharges'], df['Churn'])
print(cross_tab17)
cross_tab17.plot(kind='bar', stacked=True, color=['blue', 'green'])
plt.show()
# Out:
# Churn              0     1
# MonthlyCharges
# high             253   649
# low              361  1933
# medium          1255  2592

# %%
ratio_churn_high_monthly_char = cross_tab17.iloc[0, 1]/cross_tab17.iloc[0, 0]
print(ratio_churn_high_monthly_char)
ratio_churn_low_monthly_char = cross_tab17.iloc[1, 1]/cross_tab17.iloc[1, 0]
print(ratio_churn_low_monthly_char)
ratio_churn_med_monthly_char = cross_tab17.iloc[2, 1]/cross_tab17.iloc[2, 0]
print(ratio_churn_med_monthly_char)

# It appears that customers who have low monthly charges tend to be more likely to leave
# Out:
# 2.5652173913043477
# 5.354570637119114
# 2.065338645418327

# %%
df['TotalCharges'] = pd.to_numeric(df['TotalCharges'], errors='coerce')
# Convert column to numeric values

# %%
# low is below $1000
# Medium is between 1000 and 5000
# high above $5000
first_condition3 = df['TotalCharges'] > 5000
second_condition3 = (df['TotalCharges'] >= 1000) & (df['TotalCharges'] <= 5000)
third_condition3 = df['TotalCharges'] < 1000

filtered_df4 = df.copy()

conditions = [
    first_condition3,
    second_condition3,
    third_condition3
]

values = [
    'high',
    'medium',
    'low'
]

# Create the 'CustomerType' column based on conditions and values
df['TotalCharges'] = np.select(conditions, values)

# Display the DataFrame
print(df)
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# 1             Yes                No             DSL            Yes  ...
# 2             Yes                No             DSL            Yes  ...
# 3              No  No phone service             DSL            Yes  ...
# 4             Yes                No     Fiber optic             No  ...
# ...           ...               ...             ...            ...  ...
# 7038          Yes               Yes             DSL            Yes  ...
# 7039          Yes               Yes     Fiber optic             No  ...
# 7040           No  No phone service             DSL            Yes  ...
# 7041          Yes               Yes     Fiber optic             No  ...
# 7042          Yes                No     Fiber optic            Yes  ...
#
#      TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0             No          No              No  Month-to-month              Yes
# 1             No          No              No        One year               No
# 2             No          No              No  Month-to-month              Yes
# 3            Yes          No              No        One year               No
# 4             No          No              No  Month-to-month              Yes
# ...          ...         ...             ...             ...              ...
# 7038         Yes         Yes             Yes        One year              Yes
# 7039          No         Yes             Yes        One year              Yes
# 7040          No          No              No  Month-to-month              Yes
# 7041          No          No              No  Month-to-month              Yes
# 7042         Yes         Yes             Yes        Two year              Yes
#
#                   PaymentMethod MonthlyCharges TotalCharges Churn  \
# 0              Electronic check            low          low     1
# 1                  Mailed check         medium       medium     1
# 2                  Mailed check         medium          low     0
# 3     Bank transfer (automatic)            low       medium     1
# 4              Electronic check         medium          low     0
# ...                         ...            ...          ...   ...
# 7038               Mailed check         medium       medium     1
# 7039    Credit card (automatic)           high         high     1
# 7040           Electronic check            low          low     1
# 7041               Mailed check         medium          low     0
# 7042  Bank transfer (automatic)           high         high     1
#
#                  CustomerType
# 0                newcustomers
# 1           longtermcustomers
# 2                newcustomers
# 3       verylongtermcustomers
# 4                newcustomers
# ...                       ...
# 7038        longtermcustomers
# 7039    verylongtermcustomers
# 7040         midtermcustomers
# 7041  earlystagetermcustomers
# 7042    verylongtermcustomers
#
# [7043 rows x 22 columns]

# %%
cross_tab18 = pd.crosstab(df['TotalCharges'], df['Churn'])
print(cross_tab18)
cross_tab18.plot(kind='bar', stacked=True, color=['blue', 'green'])
plt.show()
# Out:
# Churn            0     1
# TotalCharges
# 0                0    11
# high           157   978
# low           1070  1823
# medium         642  2362

# %%
# import numpy as np
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from statsmodels.regression.linear_model import OLS

# %%
df['DeviceProtection']
# Out:
# 0        No
# 1       Yes
# 2        No
# 3       Yes
# 4        No
#        ...
# 7038    Yes
# 7039    Yes
# 7040     No
# 7041     No
# 7042    Yes
# Name: DeviceProtection, Length: 7043, dtype: object

# %%
# Split the data into training and testing sets
X = df[[  'OnlineSecurity',
          'InternetService',
          'MultipleLines',
          'PhoneService',
          'tenure',
          'Dependents', 
          'Partner',
          'SeniorCitizen',
          'gender',
          'DeviceProtection', 
          'TechSupport', 
          'StreamingTV',
          'StreamingMovies', 
           'CustomerType',
          'Contract', 
          'PaperlessBilling',
          'PaymentMethod',
           'MonthlyCharges',
           'TotalCharges']]  # Replace with your actual feature columns
y = df['Churn'] 
X = pd.get_dummies(X, columns=['PaperlessBilling', 'gender', 'MonthlyCharges', 'TotalCharges', 'PaymentMethod', 'PhoneService', 'Contract', 'MultipleLines', 'StreamingTV', 'CustomerType', 'StreamingMovies', 'InternetService', 'OnlineSecurity','TechSupport', 'Dependents', 'Partner', 'DeviceProtection'], drop_first=True)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
# Create and train the Logistic Regression model
logistic_model = LogisticRegression(max_iter=1000)

# %%
logistic_model.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
y_pred = logistic_model.predict(X_test)

# %%
accuracy = accuracy_score(y_test, y_pred)

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
conf_matrix = confusion_matrix(y_test, y_pred)

# %%
classification_rep = classification_report(y_test, y_pred)

# %%
# Print evaluation metrics
print("Accuracy:", accuracy)
print("Confusion Matrix:")
print(conf_matrix)
print("Classification Report:")
print(classification_rep)
# Out:
# Accuracy: 0.8012304779933743
# Confusion Matrix:
# [[ 306  268]
#  [ 152 1387]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.67      0.53      0.59       574
#            1       0.84      0.90      0.87      1539
#
#     accuracy                           0.80      2113
#    macro avg       0.75      0.72      0.73      2113
# weighted avg       0.79      0.80      0.79      2113

# %%
from sklearn.tree import DecisionTreeClassifier
# Out:
# dtype('int64')

# %%
# Create and train the Decision Tree Classifier model
decision_tree_model = DecisionTreeClassifier(random_state=42)
decision_tree_model.fit(X_train, y_train)
decision_tree_predictions = decision_tree_model.predict(X_test)

# %%
decision_tree_cm = confusion_matrix(y_test, decision_tree_predictions)

# %%
decision_tree_accuracy = accuracy_score(y_test, decision_tree_predictions)

# %%
decision_tree_classification_report = classification_report(y_test, decision_tree_predictions)

# %%
print("\nConfusion Matrix for Decision Tree:")
print(decision_tree_cm)
print("\nAccuracy for Decision Tree:", decision_tree_accuracy)
print("Classification Report for Decision Tree:")
print(decision_tree_classification_report)
# Out:
# Confusion Matrix for Decision Tree:
# [[ 304  270]
#  [ 311 1228]]
#
# Accuracy for Decision Tree: 0.7250354945575012
# Classification Report for Decision Tree:
#               precision    recall  f1-score   support
#
#            0       0.49      0.53      0.51       574
#            1       0.82      0.80      0.81      1539
#
#     accuracy                           0.73      2113
#    macro avg       0.66      0.66      0.66      2113
# weighted avg       0.73      0.73      0.73      2113

# %%
from sklearn.metrics import roc_curve, roc_auc_score, auc

# %%
logistic_probabilities = logistic_model.predict_proba(X_test)

# %%
decision_tree_probabilities = decision_tree_model.predict_proba(X_test)

# %%
fpr_logistic, tpr_logistic, thresholds_logistic = roc_curve(y_test, logistic_probabilities[:, 1])
auc_logistic = auc(fpr_logistic, tpr_logistic)

# %%
fpr_tree, tpr_tree, thresholds_tree = roc_curve(y_test, decision_tree_probabilities[:, 1])
auc_tree = auc(fpr_tree, tpr_tree)

# %%
plt.figure(figsize=(8, 6))
plt.plot(fpr_logistic, tpr_logistic, color='blue', lw=2, label=f'Logistic Regression (AUC = {auc_logistic:.2f})')
plt.plot(fpr_tree, tpr_tree, color='green', lw=2, label=f'Decision Tree (AUC = {auc_tree:.2f})')
plt.plot([0, 1], [0, 1], color='gray', lw=1, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curves')
plt.legend(loc='lower right')
plt.show()
